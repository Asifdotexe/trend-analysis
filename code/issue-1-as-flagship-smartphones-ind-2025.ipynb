# %%
import pandas as pd

from src.google_trends import analyze_trends

# %%
flagship_smartphones_2025 = ["iPhone 17", "Samsung S25", "Google Pixel 10", "Xiaomi 15", "Xiaomi 17", "OnePlus 13",
                             "OnePlus 15", "Oppo Find X8", "Oppo Find X9", "Vivo X200", "Vivo X300"]

# %%
analyze_trends(keyword_list=flagship_smartphones_2025, timeframe="today 3-m", geography="IN", timezone=330)
# Out:
# Connecting to Google Trends...
# Fetching data for keywords: ['iPhone 17', 'Samsung S25', 'Google Pixel 10', 'Xiaomi 15', 'Xiaomi 17', 'OnePlus 13', 'OnePlus 15', 'Oppo Find X8', 'Oppo Find X9', 'Vivo X200', 'Vivo X300'] in region: IN for timeframe: today 3-m
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 analyze_trends(keyword_list=flagship_smartphones_2025, timeframe="today 3-m", geography="IN", timezone=330)
#
# File c:\Users\sayye\OneDrive\Documents\GitHub\trend-analysis\code\src\google_trends.py:20, in analyze_trends(keyword_list, timeframe, geography, timezone, category_id)
#      17 pytrends = TrendReq(hl='en-US', tz=timezone)
#      19 print(f"Fetching data for keywords: {keyword_list} in region: {geography} for timeframe: {timeframe}")
# ---> 20 return pytrends.build_payload(
#      21             kw_list=keyword_list,
# ...
