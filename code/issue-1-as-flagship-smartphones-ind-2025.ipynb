# %%
import pandas as pd

from src.google_trends import analyze_trends

# %%
flagship_smartphones_2025 = ["iPhone 17", "Samsung S25", "Google Pixel 10", "OnePlus 13",
                             "OnePlus 15"]

# %%
analyze_trends(keyword_list=flagship_smartphones_2025, timeframe="today 3-m", geography="IN", timezone=330)
# Out:
# Connecting to Google Trends...
# Fetching data for keywords: ['iPhone 17', 'Samsung S25', 'Google Pixel 10', 'OnePlus 13', 'OnePlus 15'] in region: IN for timeframe: today 3-m
